# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Things To Consider
#
# Sunlight and humidity levels influence the production of orchids.
#
# 1. When sunlight exposure is less than 7 hours a day, production will decrease with 4% for every 10 minutes
#     - Average sunlight per hour is 2500 units
#     - So when sunlight units is less than 7 x 2_500 = 17_500, then production will decrease
# 2. Ideal humidity is between 60% to 80%:
#     - Outside those limits, production will fall 2% for every 5% in humidity change
# 3. Import/Export tariffs
# 4. Storage Costs

# %%
# !dir "../csv/round-2-island-data-bottle/"
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 4C9C-5B8B
#
#  Directory of C:\Users\joshu\Documents\Code\prosperity2\csv\round-2-island-data-bottle
#
# 2024-04-12  02:59 PM    <DIR>          .
# 2024-04-12  02:59 PM    <DIR>          ..
# 2024-04-12  02:59 PM           509,742 prices_round_2_day_-1.csv
# 2024-04-12  02:59 PM           498,397 prices_round_2_day_0.csv
# 2024-04-12  02:59 PM           497,555 prices_round_2_day_1.csv
#                3 File(s)      1,505,694 bytes
#                2 Dir(s)  47,005,294,592 bytes free

# %%
pricesByDay = {}
for day in [-1, 0, 1]:
    pricesByDay[day] = pd.read_csv(f"../csv/round-2-island-data-bottle/prices_round_2_day_{day}.csv", sep=';')

# %%
pricesByDay[-1].head()
# Out:
#    timestamp  ORCHIDS  TRANSPORT_FEES  EXPORT_TARIFF  IMPORT_TARIFF  \
# 0          0  1200.00             1.5           10.5           -2.0
# 1        100  1201.75             1.5            9.5           -2.0
# 2        200  1201.75             1.5            9.5           -2.0
# 3        300  1201.75             1.5            9.5           -2.0
# 4        400  1201.75             1.5            9.5           -2.0
#
#     SUNLIGHT  HUMIDITY  DAY
# 0  2500.0000  79.00000   -1
# 1  2499.4197  79.00410   -1
# 2  2498.8457  79.00821   -1
# 3  2498.2780  79.01234   -1
# 4  2497.7166  79.01649   -1

# %%
pricesByDay[0].describe()
# Out:
#             timestamp       ORCHIDS  TRANSPORT_FEES  EXPORT_TARIFF  \
# count    10001.000000  10001.000000    10001.000000   10001.000000
# mean    500000.000000   1041.251175        1.384912       9.961154
# std     288718.435504     45.142712        0.193678       1.584335
# min          0.000000    960.750000        1.100000       8.500000
# 25%     250000.000000   1001.750000        1.300000       9.500000
# 50%     500000.000000   1039.250000        1.300000       9.500000
# 75%     750000.000000   1083.250000        1.500000      10.500000
# max    1000000.000000   1122.000000        2.100000      19.500000
#
#        IMPORT_TARIFF      SUNLIGHT      HUMIDITY      DAY
# count   10001.000000  10001.000000  10001.000000  10001.0
# mean       -2.570763   2279.533353     74.036523      0.0
# std         0.349321    813.568530     10.199225      0.0
# min        -4.200000   1397.304900     59.999580      0.0
# 25%        -2.600000   1811.042400     67.049130      0.0
# 50%        -2.600000   2000.000000     70.277214      0.0
# 75%        -2.400000   2400.000000     83.000000      0.0
# max        -2.000000   4500.338000     95.000000      0.0

# %%
pricesByDay[1].describe()
# Out:
#             timestamp       ORCHIDS  TRANSPORT_FEES  EXPORT_TARIFF  \
# count    10001.000000  10001.000000    10001.000000   10001.000000
# mean    500000.000000   1060.797645        0.926107       9.151935
# std     288718.435504     29.101624        0.164156       0.807551
# min          0.000000   1009.250000        0.700000       7.500000
# 25%     250000.000000   1038.750000        0.800000       8.500000
# 50%     500000.000000   1053.750000        0.900000       9.500000
# 75%     750000.000000   1080.750000        1.000000       9.500000
# max    1000000.000000   1133.250000        1.700000      13.500000
#
#        IMPORT_TARIFF      SUNLIGHT      HUMIDITY      DAY
# count   10001.000000  10001.000000  10001.000000  10001.0
# mean       -5.054445   2431.936381     77.562755      1.0
# std         0.546315    676.201827      8.010117      0.0
# min        -6.500000   1669.296600     67.536980      1.0
# 25%        -5.500000   1951.776000     72.174774      1.0
# 50%        -5.000000   2219.208300     74.889440      1.0
# 75%        -4.500000   2608.087400     79.031670      1.0
# max        -4.500000   4219.218000     97.513270      1.0

# %%
# Predict the orchids value in next timestamp

for day in [-1, 0, 1]:
    df = pricesByDay[day]
    df['ORCHIDSNEXT'] = df['ORCHIDS'].shift(-1)
    pricesByDay[day] = df.iloc[:-1]

# %%
pricesByDay[-1].tail()
# Out:
#       timestamp  ORCHIDS  TRANSPORT_FEES  EXPORT_TARIFF  IMPORT_TARIFF  \
# 9995     999500  1228.75             1.4            8.5           -3.0
# 9996     999600  1227.75             1.4            8.5           -3.0
# 9997     999700  1226.75             1.4            8.5           -3.0
# 9998     999800  1227.75             1.4            8.5           -3.0
# 9999     999900  1228.00             1.4            8.5           -3.0
#
#        SUNLIGHT   HUMIDITY  DAY  ORCHIDSNEXT
# 9995  3902.4468  83.032240   -1      1227.75
# 9996  3901.9530  83.025764   -1      1226.75
# 9997  3901.4612  83.019300   -1      1227.75
# 9998  3900.9720  83.012856   -1      1228.00
# 9999  3900.4849  83.006424   -1      1228.00

# %%
cols = [
    'ORCHIDS',
    'TRANSPORT_FEES',
    'EXPORT_TARIFF',
    'IMPORT_TARIFF',
    'SUNLIGHT',
    'HUMIDITY',
    'ORCHIDSNEXT'
]

# %%
modified_pricesByDay = {}

for day in [-1, 0, 1]:
    modified_pricesByDay[day] = pricesByDay[day].loc[:, cols].copy()

modified_pricesByDay[-1].head()
# Out:
#    ORCHIDS  TRANSPORT_FEES  EXPORT_TARIFF  IMPORT_TARIFF   SUNLIGHT  HUMIDITY  \
# 0  1200.00             1.5           10.5           -2.0  2500.0000  79.00000
# 1  1201.75             1.5            9.5           -2.0  2499.4197  79.00410
# 2  1201.75             1.5            9.5           -2.0  2498.8457  79.00821
# 3  1201.75             1.5            9.5           -2.0  2498.2780  79.01234
# 4  1201.75             1.5            9.5           -2.0  2497.7166  79.01649
#
#    ORCHIDSNEXT
# 0      1201.75
# 1      1201.75
# 2      1201.75
# 3      1201.75
# 4      1200.25

# %%
X_day, y_day = {}, {}
for day in [-1, 0, 1]:
    X_day[day] = modified_pricesByDay[day].iloc[:, :-1].to_numpy()
    y_day[day] = modified_pricesByDay[day].iloc[:, [-1]].to_numpy()

# %%
X_day[-1][:5], y_day[-1][:5]
# Out:
# (array([[ 1.2000000e+03,  1.5000000e+00,  1.0500000e+01, -2.0000000e+00,
#           2.5000000e+03,  7.9000000e+01],
#         [ 1.2017500e+03,  1.5000000e+00,  9.5000000e+00, -2.0000000e+00,
#           2.4994197e+03,  7.9004100e+01],
#         [ 1.2017500e+03,  1.5000000e+00,  9.5000000e+00, -2.0000000e+00,
#           2.4988457e+03,  7.9008210e+01],
#         [ 1.2017500e+03,  1.5000000e+00,  9.5000000e+00, -2.0000000e+00,
#           2.4982780e+03,  7.9012340e+01],
#         [ 1.2017500e+03,  1.5000000e+00,  9.5000000e+00, -2.0000000e+00,
#           2.4977166e+03,  7.9016490e+01]]),
#  array([[1201.75],
#         [1201.75],
#         [1201.75],
#         [1201.75],
#         [1200.25]]))

# %%
X_combined = np.concatenate([X_day[i] for i in [-1, 0, 1]])
y_combined = np.concatenate([y_day[i] for i in [-1, 0, 1]])

# %%
X_combined.shape, y_combined.shape
# Out:
# ((30000, 6), (30000, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
lm_day = {}
for day in [-1, 0, 1]:
    lm_day[day] = LinearRegression().fit(X_day[day], y_day[day])
    print(f"Day {day}: intercept = {lm_day[day].intercept_}\n\t coef = {lm_day[day].coef_}\n")
    
lm_combined = LinearRegression().fit(X_combined, y_combined)
print(f"Combined: intercept = {lm_combined.intercept_}\n\t coef = {lm_combined.coef_}\n")
# Out:
# Day -1: intercept = [2.37385736]
# 	 coef = [[9.97581796e-01 3.90973335e-02 6.10237333e-06 2.13058665e-02
#   5.42280630e-05 4.15978456e-03]]
#
# Day 0: intercept = [1.54410778]
# 	 coef = [[ 9.98120010e-01 -1.09455279e-01  2.33860715e-02  2.79407389e-02
#    2.21718797e-05  4.60262185e-03]]
#
# Day 1: intercept = [1.45616804]
# 	 coef = [[ 9.98372618e-01  1.56943333e-01 -1.85791023e-02 -1.35174648e-02
#    4.90294647e-06  2.68553807e-03]]
#
# Combined: intercept = [0.06987954]
# 	 coef = [[ 9.99711443e-01  1.09677694e-02  6.46992420e-03 -2.80465300e-03
#    1.75439458e-05  1.37126605e-03]]

# %%
df = pd.read_csv("~/Downloads/245d2c03-746d-4c6b-ab57-20739a2e623e.csv", sep=';')

# %%
df[df['profit_and_loss'] > 0]
# Out:
#       day  timestamp  product  bid_price_1  bid_volume_1  bid_price_2  \
# 245     1       8100  ORCHIDS         1093             6       1092.0
# 247     1       8200  ORCHIDS         1092             5       1091.0
# 250     1       8300  ORCHIDS         1092             6       1091.0
# 253     1       8400  ORCHIDS         1093             9       1092.0
# 257     1       8500  ORCHIDS         1093             7       1092.0
# ...   ...        ...      ...          ...           ...          ...
# 2986    1      99500  ORCHIDS         1067             5       1066.0
# 2988    1      99600  ORCHIDS         1068             7       1067.0
# 2991    1      99700  ORCHIDS         1068             5       1067.0
# 2996    1      99800  ORCHIDS         1068             8       1067.0
# 2998    1      99900  ORCHIDS         1067             7       1066.0
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 245            2.0       1085.0          47.0         1101             6
# 247            2.0       1084.0          43.0         1100             5
# 250            4.0       1085.0          43.0         1100             6
# 253            3.0       1086.0          46.0         1101             9
# 257            2.0       1085.0          39.0         1101             7
# ...            ...          ...           ...          ...           ...
# 2986           4.0       1060.0          43.0         1074             5
# 2988           2.0       1061.0          46.0         1075             7
# 2991           3.0       1061.0          48.0         1076             5
# 2996           3.0       1061.0          49.0         1075             8
# 2998           4.0       1059.0          49.0         1074             7
#
#       ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 245        1102.0           2.0       1108.0          47.0     1097.0
# 247        1101.0           2.0       1107.0          43.0     1096.0
# 250        1101.0           4.0       1108.0          43.0     1096.0
# 253        1102.0           3.0       1109.0          46.0     1097.0
# 257        1102.0           2.0       1108.0          39.0     1097.0
# ...           ...           ...          ...           ...        ...
# 2986       1075.0           4.0       1082.0          43.0     1070.5
# 2988       1076.0           2.0       1083.0          46.0     1071.5
# 2991       1077.0           3.0       1083.0          48.0     1072.0
# 2996       1076.0           3.0       1083.0          49.0     1071.5
# 2998       1075.0           4.0       1081.0          49.0     1070.5
#
#       profit_and_loss
# 245       2198.000000
# 247       2198.000000
# 250       2198.000000
# 253       2198.000000
# 257       2198.000000
# ...               ...
# 2986      5495.919922
# 2988      5495.919922
# 2991      5495.919922
# 2996      5495.919922
# 2998       162.919922
#
# [247 rows x 17 columns]

# %%
ind = (df["profit_and_loss"] < 0) & (df["profit_and_loss"] > 0) & (df['timestamp'] > 80_000)

# %%
df[ind]
# Out:
# Empty DataFrame
# Columns: [day, timestamp, product, bid_price_1, bid_volume_1, bid_price_2, bid_volume_2, bid_price_3, bid_volume_3, ask_price_1, ask_volume_1, ask_price_2, ask_volume_2, ask_price_3, ask_volume_3, mid_price, profit_and_loss]
# Index: []

# %%
mask = (df['product'] == "ORCHIDS")
df_orchids = df[mask]
fig, ax = plt.subplots(figsize=(15, 7))
ax.plot(df_orchids.timestamp, df_orchids.profit_and_loss)

# %%
df_orchids.tail()
# Out:
#       day  timestamp  product  bid_price_1  bid_volume_1  bid_price_2  \
# 2986    1      99500  ORCHIDS         1067             5       1066.0
# 2988    1      99600  ORCHIDS         1068             7       1067.0
# 2991    1      99700  ORCHIDS         1068             5       1067.0
# 2996    1      99800  ORCHIDS         1068             8       1067.0
# 2998    1      99900  ORCHIDS         1067             7       1066.0
#
#       bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 2986           4.0       1060.0          43.0         1074             5
# 2988           2.0       1061.0          46.0         1075             7
# 2991           3.0       1061.0          48.0         1076             5
# 2996           3.0       1061.0          49.0         1075             8
# 2998           4.0       1059.0          49.0         1074             7
#
#       ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 2986       1075.0           4.0       1082.0          43.0     1070.5
# 2988       1076.0           2.0       1083.0          46.0     1071.5
# 2991       1077.0           3.0       1083.0          48.0     1072.0
# 2996       1076.0           3.0       1083.0          49.0     1071.5
# 2998       1075.0           4.0       1081.0          49.0     1070.5
#
#       profit_and_loss
# 2986      5495.919922
# 2988      5495.919922
# 2991      5495.919922
# 2996      5495.919922
# 2998       162.919922
